# %%
import pandas as pd
# # age = pd.Series([11,"Moaz",33], index =['A','B','C'])
# # print(age)
# # print("#",20)
# student_info =pd.DataFrame({
#     'name':["Moaz","Ahmed","Omar"],
#     'Age':[20,19,22],
#     'isGraduate':[True,False,False]
# }, index=['A','AA','AAA'])
# print(student_info)
df = pd.read_excel('employees_data_50.xlsx')
# print(df['Employee_ID'])
print(df.iloc[0])
print('='*40)
print(df.loc[0])
# Out:
# Employee_ID                        EMP001
# Name                       Hassan Ibrahim
# Age                                    29
# Gender                               Male
# Department                     Operations
# Job_Title                     Team Leader
# Salary                               7819
# Bonus                                1339
# Years_Experience                       11
# Join_Date             2020-04-01 00:00:00
# City                             Mansoura
# Performance_Rating                    2.7
# Is_Active                           False
# Name: 0, dtype: object
# ...
# Employee_ID                        EMP001
# Name                       Hassan Ibrahim
# Age                                    29
# Gender                               Male
# Department                     Operations
# Job_Title                     Team Leader
# Salary                               7819
# Bonus                                1339
# Years_Experience                       11
# ...

# %%
# print(df.iloc[0,2])
# print(df.loc[0,'Age'])
print(df[df['Salary']>1000])
# Out:
#    Employee_ID             Name  Age  Gender        Department  \
# 0       EMP001   Hassan Ibrahim   29    Male        Operations
# 1       EMP002      Amr Ibrahim   38    Male                IT
# 2       EMP003     George Kamel   30    Male  Customer Service
# 3       EMP004    Hassan Hassan   45  Female  Customer Service
# 4       EMP005  Mohamed Ibrahim   31    Male             Sales
# 5       EMP006        Amr Samir   44    Male                HR
# 6       EMP007     Ziad Ibrahim   43  Female           Finance
# 7       EMP008    Ibrahim Kamel   28  Female           Finance
# 8       EMP009    Ibrahim Fathy   33    Male        Operations
# 9       EMP010      George Said   24  Female                HR
# 10      EMP011       Ziad Samir   42  Female        Operations
# 11      EMP012    Youssef Samir   42    Male             Sales
# 12      EMP013        Ahmed Ali   33  Female             Sales
# 13      EMP014     Ziad Mohamed   26  Female        Operations
# ...

# %%
print(df.at[0,'Salary'])
print(df.iat[0,3])
# Out:
# 7819
# Male

# %%
data ={
    'name':['Moaz','Ali','Omar'],
    'Age':[25,30,22],
    'Mark':[88,67,70]
}
df = pd.DataFrame(data)
# print(df)
# print(df.index)
# print(df.columns)
# print(df.values)
# print(df.dtypes)
# print(df.shape)# المصفوفه كام ف كام
# print(df.ndim)# المصفوفه اللى معاك الDimention بتاعها ايه ؟؟
# # فيه :->Size , Empty 
# print(df.T) # بيعكس بيخلى الصف عمود و العكس
# print(df.isna())# بيرجع لو فيه حاجه ف الجدول فاضيه مش موجوده وفيه داله عكسها اسمها : notna(Not Available)
# print(df.describe)# بيجيب حجات احصائيه زي ال count , mean , std , max
print()
# print(df.info())
print(df.head(2))
print(df.tail(2))
df
# Out:
#    name  Age  Mark
# 0  Moaz   25    88
# 1   Ali   30    67
#    name  Age  Mark
# 1   Ali   30    67
# 2  Omar   22    70
#    name  Age  Mark
# 0  Moaz   25    88
# 1   Ali   30    67
# 2  Omar   22    70
