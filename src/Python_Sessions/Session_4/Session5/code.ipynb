# %%
"""
THis Class For tabbaaaaannn
"""


class StudentInfo:
    name = "Moaz num1"
    Age = 10
    def std_info(self):
        print(self.name)
        # print(help(self))
        print(dir(self))

# %%
"""
THis Class For tabbaaaaannn
"""


class StudentInfo:
    name = "Moaz num1"
    Age = 10
    def std_info(self):
        print(self.name)
        print(help(self))

# %%
s1 = StudentInfo()
s2 = StudentInfo()
s1.name = "Moaz"
s1.Age = 500000
s1.std_info()
print(s1.name)
print(s1.Age)
s1.std_info()
s2.std_info()
# Out:
# Moaz
# ['Age', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__firstlineno__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__static_attributes__', '__str__', '__subclasshook__', '__weakref__', 'name', 'std_info']
# Moaz num1
# ['Age', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__firstlineno__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__static_attributes__', '__str__', '__subclasshook__', '__weakref__', 'name', 'std_info']
# Moaz
# 500000
# Moaz
# ...

# %%
class Student:

# __name of func__ >>> dounden Function 
    def __init__(self,name:str = "Moaz" , age:int = 10):
        self.name = name
        self.age = age

    def std_info(self):
        print(self.name , self.age)
# Out:
#   Cell In[18], line 2
#     def _init_()
#                 ^
# SyntaxError: expected ':'

# %%
from abc import ABC , abstractmethod
class Animal(ABC):
    @abstractmethod  # Decorator
    def move(self):
        pass
class Bird(Animal):
    def move(self):
        print("From Bird")
class cat(Animal):
    print("From Cat")
# Out:
# From Cat

# %%
a = Bird()
a.move()
# Out:
# From Bird

# %%
# _ protect
# __ private
class Employee :
    def __int__(self , name ,salary):
        self.name = name
        self.salary = salary
    def set_salary(self , obj ,new_salary):
        obj.salary = new_salary


class  Manager:
    def __init__(self , name , salary):
        self.name = name
        self._salary = salary

# %%
E1= Employee("Moaz",2000)

# %%
class A():
    def do_this(self):
        print("Tabaaaaaaaan Lak")
class B(A):
    pass

class C():
    def do_this(self):
        print("Im in c")
class D(C , B):
    pass
